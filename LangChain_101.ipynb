# %%
# save the openapi_key here
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature = 0.6)
llm("I want to open a restaurant for Indian food. Suggest a fancy name for this.")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from langchain.llms import OpenAI
#       3 llm = OpenAI(temperature = 0.6)
# ----> 4 llm("I want to open a restaurant for Indian food. Suggest a fancy name for this.")
#
# File ~\anaconda3\envs\ml\Lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\langchain_core\language_models\llms.py:1050, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1043 if not isinstance(prompt, str):
#    1044     raise ValueError(
#    1045         "Argument `prompt` is expected to be a string. Instead found "
# ...
